# %%
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.manifold import TSNE

# %%
#Downloading The digits dataset

digits = datasets.load_digits()

# optional print statements
# print digits['images'], digits['target']
# print digits['images'][0].shape
# flattening the 2D Array to 1D Array

flatten = []

for eachDigit in digits['images']:
    temp = []
    for eachrow in eachDigit:
        temp.extend(eachrow)
    flatten.append(temp)

# plotting with t-nse 
X_tsne = TSNE(learning_rate=200, n_components=2, perplexity=40, verbose=2).fit_transform(flatten)

plt.figure(figsize=(10, 5))

plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=digits['target'])

plt.show()
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 8.394135
# [t-SNE] Iteration 25: error = 2.4654746, gradient norm = 0.0039884
# [t-SNE] Iteration 50: error = 2.3543985, gradient norm = 0.0202036
# [t-SNE] Iteration 75: error = 1.5194389, gradient norm = 0.0050455
# [t-SNE] Iteration 100: error = 1.4177896, gradient norm = 0.0041629
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 1.417790
# [t-SNE] Iteration 125: error = 1.2733165, gradient norm = 0.0030025
# [t-SNE] Iteration 150: error = 1.2322143, gradient norm = 0.0027209
# [t-SNE] Iteration 175: error = 1.2222492, gradient norm = 0.0026570
# [t-SNE] Iteration 200: error = 1.2195716, gradient norm = 0.0026411
# [t-SNE] Iteration 225: error = 1.2188349, gradient norm = 0.0026367
# [t-SNE] Iteration 250: error = 1.2186315, gradient norm = 0.0026360
# [t-SNE] Iteration 275: error = 1.2185822, gradient norm = 0.0026356
# [t-SNE] Iteration 300: error = 1.2185673, gradient norm = 0.0026355
# [t-SNE] Iteration 325: error = 1.2185626, gradient norm = 0.0026355
# [t-SNE] Iteration 350: error = 1.2185616, gradient norm = 0.0026355
# [t-SNE] Iteration 350: error difference 0.000000. Finished.
# [t-SNE] Error after 350 iterations: 1.417790
